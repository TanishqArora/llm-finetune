# %%
# pip install ipykernel
# python -m ipykernel install --user --name=myenv --display-name "dev-env"

# %%
# fine_tune_demo.ipynb
# Step 1: Imports
import os
import json
from datasets import load_dataset, Dataset
import torch
from transformers import AutoModelForCausalLM, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from peft import LoraConfig, get_peft_model, TaskType
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2302, in _LazyModule.__getattr__(self, name)
#    2301 try:
# -> 2302     module = self._get_module(self._class_to_module[name])
#    2303     value = getattr(module, name)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2332, in _LazyModule._get_module(self, module_name)
#    2331 except Exception as e:
# -> 2332     raise e
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2330, in _LazyModule._get_module(self, module_name)
#    2329 try:
# -> 2330     return importlib.import_module("." + module_name, self.__name__)
#    2331 except Exception as e:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:70
#      61 from .integrations.tensor_parallel import (
#      62     _get_parameter_tp_plan,
#      63     distribute_model,
#    (...)
#      68     verify_tp_plan,
#      69 )
# ---> 70 from .loss.loss_utils import LOSS_MAPPING
#      71 from .modeling_flash_attention_utils import lazy_import_flash_attention
#
# File /opt/conda/lib/python3.10/site-packages/transformers/loss/loss_utils.py:21
#      19 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 21 from .loss_d_fine import DFineForObjectDetectionLoss
#      22 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#
# File /opt/conda/lib/python3.10/site-packages/transformers/loss/loss_d_fine.py:21
#      20 from ..utils import is_vision_available
# ---> 21 from .loss_for_object_detection import (
#      22     box_iou,
#      23 )
#      24 from .loss_rt_detr import RTDetrHungarianMatcher, RTDetrLoss
#
# File /opt/conda/lib/python3.10/site-packages/transformers/loss/loss_for_object_detection.py:32
#      31 if is_vision_available():
# ---> 32     from transformers.image_transforms import center_to_corners_format
#      35 def dice_loss(inputs, targets, num_boxes):
#
# File /opt/conda/lib/python3.10/site-packages/transformers/image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File /opt/conda/lib/python3.10/site-packages/transformers/image_utils.py:60
#      59 if is_torchvision_available():
# ---> 60     from torchvision.transforms import InterpolationMode
#      62     pil_torch_interpolation_mapping = {
#      63         PILImageResampling.NEAREST: InterpolationMode.NEAREST_EXACT
#      64         if is_torchvision_v2_available()
#    (...)
#      70         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      71     }
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/__init__.py:6
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#
# File /opt/conda/lib/python3.10/site-packages/torchvision/_meta_registrations.py:164
#     160     return grad.new_empty((batch_size, channels, height, width))
#     163 @torch._custom_ops.impl_abstract("torchvision::nms")
# --> 164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#
# File /opt/conda/lib/python3.10/site-packages/torch/library.py:1069, in register_fake.<locals>.register(func)
#    1068     use_lib = lib
# -> 1069 use_lib._register_fake(
#    1070     op_name, func, _stacklevel=stacklevel + 1, allow_override=allow_override
#    1071 )
#    1072 return func
#
# File /opt/conda/lib/python3.10/site-packages/torch/library.py:219, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     217     func_to_register = fn
# --> 219 handle = entry.fake_impl.register(
#     220     func_to_register, source, lib=self, allow_override=allow_override
#     221 )
#     222 self._registration_handles.append(handle)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_library/fake_impl.py:50, in FakeImplHolder.register(self, func, source, lib, allow_override)
#      45     raise RuntimeError(
#      46         f"register_fake(...): the operator {self.qualname} "
#      47         f"already has an fake impl registered at "
#      48         f"{self.kernel.source}."
#      49     )
# ---> 50 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      51     raise RuntimeError(
#      52         f"register_fake(...): the operator {self.qualname} "
#      53         f"already has an DispatchKey::Meta implementation via a "
#    (...)
#      56         f"register_fake."
#      57     )
#
# RuntimeError: operator torchvision::nms does not exist
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2302, in _LazyModule.__getattr__(self, name)
#    2301 try:
# -> 2302     module = self._get_module(self._class_to_module[name])
#    2303     value = getattr(module, name)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2332, in _LazyModule._get_module(self, module_name)
#    2331 except Exception as e:
# -> 2332     raise e
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2330, in _LazyModule._get_module(self, module_name)
#    2329 try:
# -> 2330     return importlib.import_module("." + module_name, self.__name__)
#    2331 except Exception as e:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/integrations/integration_utils.py:44
#      42     print("⚙️  Running in WANDB offline mode")
# ---> 44 from .. import PreTrainedModel, TrainingArguments
#      45 from .. import __version__ as version
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2305, in _LazyModule.__getattr__(self, name)
#    2304     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2305         raise ModuleNotFoundError(
#    2306             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2307         ) from e
#    2309 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'PreTrainedModel'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2302, in _LazyModule.__getattr__(self, name)
#    2301 try:
# -> 2302     module = self._get_module(self._class_to_module[name])
#    2303     value = getattr(module, name)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2332, in _LazyModule._get_module(self, module_name)
#    2331 except Exception as e:
# -> 2332     raise e
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2330, in _LazyModule._get_module(self, module_name)
#    2329 try:
# -> 2330     return importlib.import_module("." + module_name, self.__name__)
#    2331 except Exception as e:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:42
#      40 # Integrations must be imported before ML frameworks:
#      41 # ruff: isort: off
# ---> 42 from .integrations import (
#      43     get_reporting_integration_callbacks,
#      44 )
#      46 # ruff: isort: on
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2305, in _LazyModule.__getattr__(self, name)
#    2304     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2305         raise ModuleNotFoundError(
#    2306             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2307         ) from e
#    2309 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'get_reporting_integration_callbacks'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from datasets import load_dataset, Dataset
#       6 import torch
# ----> 7 from transformers import AutoModelForCausalLM, Trainer, TrainingArguments, DataCollatorForLanguageModeling
#       8 from peft import LoraConfig, get_peft_model, TaskType
#       9 from transformers import pipeline
#
# File /opt/conda/lib/python3.10/site-packages/transformers/utils/import_utils.py:2305, in _LazyModule.__getattr__(self, name)
#    2303         value = getattr(module, name)
#    2304     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2305         raise ModuleNotFoundError(
#    2306             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2307         ) from e
#    2309 elif name in self._modules:
#    2310     try:
#
# ModuleNotFoundError: Could not import module 'Trainer'. Are this object's requirements defined correctly?
